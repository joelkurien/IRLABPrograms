# %%
# !pip install concepts
# Out:
# Requirement already satisfied: concepts in /usr/local/lib/python3.7/dist-packages (0.9.2)
# Requirement already satisfied: bitsets~=0.7 in /usr/local/lib/python3.7/dist-packages (from concepts) (0.8.2)
# Requirement already satisfied: graphviz~=0.7 in /usr/local/lib/python3.7/dist-packages (from concepts) (0.10.1)

# %%
from concepts import Context, load_cxt, make_context, load_csv
import graphviz
import numpy as np
import pandas as pd

# %%
c = Context.fromstring('''
 |D1 |D2 |D3 |D4 |
a| X | X |   |   |
b| X |   | X |   |
c|   | X |   | X |
d|   |   | X | X |
''')

c
# c.tofile(filename='context.csv', format='csv')
# Out:
# <Context object mapping 4 objects to 4 properties [4135d62c] at 0x7f3a85af86d0>

# %%
c.lattice.graphviz()
